# %% [markdown]
# # Plain-DNN for magnetic field

# %% [markdown]
# ## Navigating to the working directory containing the datasets and model

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.4.1

# %%
from platform import python_version
print(python_version())
# Out:
# 3.9.5

# %%
source_file = False

if source_file:
  from google.colab import drive
  drive.mount('/content/drive')
  source_file = '/content/drive/MyDrive/Data_and_mode/Datasets_for_magfield'

else:
  source_file = '/clusterdata/uqvngu19/Data_and_model'

# %% [markdown]
# ## Checking the current working GPU

# %%
# !nvidia-smi
# Out:
# Mon Oct 18 01:13:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    34W / 300W |   6745MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      3585      C   ...opc/miniconda3/bin/python     6743MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Loading the datasets and doing feature engineering

# %%
# Loading data

import pickle
import os

# source_file_data_111 = '/content/drive/My Drive/part_C_all_1'
# os.chdir(source_file_data_111)

# with open('all_1_para', 'rb') as file_para:
#     para = pickle.load(file_para)
    
# with open('all_1_output_field', 'rb') as file_out:
#     output_field = pickle.load(file_out)
source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Datasets_for_magfield/Dataset_4m'

os.chdir(source_file)

with open('para_4m', 'rb') as file_para:
    para = pickle.load(file_para)
    
with open('output_field_4m', 'rb') as file_out:
    output_field = pickle.load(file_out)


# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
import os
#os.chdir('Datasets_for_magfield')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Data_and_model/Datasets_for_magfield'

# %% [markdown]
# ## Data cleaning

# %%
# cleaning data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle

random.seed(123)

para_np = np.array(para)
output_field_np = np.array(output_field)

index = 1

q1, q3 = np.percentile(output_field_np[:, index], [25, 75])

upper = q3 + 1.5*(q3-q1)
lower = q1 - 1.5*(q3-q1)

mask = (output_field_np[:, index] > lower)*(output_field_np[:, index] < upper)

mask_index = np.where(mask)[0]

clean_1 = output_field_np[:, index][mask]

para_1 = para_np[mask_index]

#x_train, x_test, y_train, y_test = train_test_split(para_np, output_field_np, test_size=.20, shuffle=True)

# %%
upper = q3 + 1.5*(q3-q1)
lower = q1 - 1.5*(q3-q1)
print(lower, upper)
# Out:
# -3390.5330681265636 3387.6447204701713

# %%
import seaborn as sns
sns.distplot(clean_1, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.hist(clean_1)
# plt.hist(output_field_np[:, 0])
#sns.distplot(output_field_np[:, 0], kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# (array([ 68043.,  90589., 131639., 219657., 901594., 960545., 219071.,
#         131865.,  91174.,  68012.]),
#  array([-3.38960885e+03, -2.71173654e+03, -2.03386423e+03, -1.35599192e+03,
#         -6.78119614e+02, -2.47304607e-01,  6.77625004e+02,  1.35549731e+03,
#          2.03336962e+03,  2.71124193e+03,  3.38911424e+03]),
#  <BarContainer object of 10 artists>)

# %%
# mask = np.argwhere(output_field_np <= q3)
# mask.shape

from matplotlib import pyplot as plt

plt.hist(para_1[:,0])

#np.unique(output_field_np[:, 0], return_counts=True)
# Out:
# (array([351522., 328556., 311583., 298565., 286625., 278020., 269137.,
#         261428., 252173., 244580.]),
#  array([ 3.00005354,  7.70004723, 12.40004092, 17.10003461, 21.80002831,
#         26.500022  , 31.20001569, 35.90000938, 40.60000307, 45.29999676,
#         49.99999046]),
#  <BarContainer object of 10 artists>)

# %%
output_field_np.shape
# Out:
# (4000000, 3)

# %% [markdown]
# ## Feature engineering for clean data

# %%
#
# Feature engineering

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle
import os

random.seed(123)

# folder_ = os.path.join(source_file, 'new_data_IQR')
# os.chdir(folder_)

para_np = para_1 #np.array(para)
output_field_np = clean_1 #np.array(output_field)

#q1, q3 = np.percentile(output_field_np, [5, 95])

x_train, x_test, y_train, y_test = train_test_split(para_np, output_field_np, test_size=.10, shuffle=True)

x_sScaler = StandardScaler()
x_sScaler.fit(x_train)
s_x_train_scaled = x_sScaler.transform(x_train)
s_x_test_scaled = x_sScaler.transform(x_test)

y_sScaler = StandardScaler()
y_sScaler.fit(y_train.reshape(-1, 1))
s_y_train_scaled = y_sScaler.transform(y_train.reshape(-1, 1))
s_y_test_scaled = y_sScaler.transform(y_test.reshape(-1, 1))


# # Saving training, testing and scalers data


with open('re_s_x_train_scaled_az', 'wb') as filename:
  pickle.dump(s_x_train_scaled, filename)

with open('re_s_y_train_scaled_az', 'wb') as filename:
  pickle.dump(s_y_train_scaled, filename)

with open('re_s_x_test_scaled_az', 'wb') as filename:
  pickle.dump(s_x_test_scaled, filename)

with open('re_s_y_test_scaled_az', 'wb') as filename:
  pickle.dump(s_y_test_scaled, filename)

with open('re_x_sScaler_az', 'wb') as filename:
  pickle.dump(x_sScaler, filename)

with open('re_y_sScaler_az', 'wb') as filename:
  pickle.dump(y_sScaler, filename)

# %%
os.getcwd()
# Out:
# '/content'

# %% [markdown]
# ## Loading ready processed datasets

# %%
import pickle
import os

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Datasets_for_magfield/Dataset_4m'

#source_file_rd = os.path.join(source_file, 'new_data_IQR')

os.chdir(source_file)

with open('re_s_x_train_scaled_az', 'rb') as filename:
  s_x_train_scaled = pickle.load(filename)

with open('re_s_y_train_scaled_az', 'rb') as filename:
  s_y_train_scaled = pickle.load(filename)

with open('re_s_x_test_scaled_az', 'rb') as filename:
  s_x_test_scaled = pickle.load(filename)

with open('re_s_y_test_scaled_az', 'rb') as filename:
  s_y_test_scaled = pickle.load(filename)

with open('re_x_sScaler_az', 'rb') as filename:
  x_sScaler = pickle.load(filename)

with open('re_y_sScaler_az', 'rb') as filename:
  y_sScaler = pickle.load(filename)

# importing data for out of training intervals

# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
s_x_test_scaled.shape
# Out:
# (288219, 9)

# %%
import numpy as np
min_ = np.min(s_y_train_scaled)
max_ = np.max(s_y_train_scaled)

out_min_ = np.min(out_y_scaled)
out_max_ = np.max(out_y_scaled)
print(f'Field interval for the training data is: [{min_}, {max_}]')
print(f'Field interval for the out of training intervals is: [{out_min_}, {out_max_}]')
# Out:
# Field interval for the training data is: [-23.610358434445427, 23.999540757658966]
# Field interval for the out of training intervals is: [-2.3426246433144176, 2.2994854937939446]

# %%
with open('out_para_200k', 'rb') as filename:
  out_para_scaled = pickle.load(filename)

# %%
x_train.shape
# Out:
# (900000, 9)

# %% [markdown]
# ## PlainDNN model development

# %%
# Plain DNN model


import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation


# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

class PlainDNNModel(tf.keras.Model):
    def __init__(self):
        
        super(PlainDNNModel, self).__init__()
        
        self.dense1_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense2_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense3_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_4 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_o = tf.keras.layers.Dense(1)

        
    def call(self, inputs):
        
        x_1 = self.dense1_1(inputs)
        x_1 = self.dense1_2(x_1)
        x_1 = self.dense1_3(x_1)

        
        x_2 = self.dense2_1(x_1)
        x_2 = self.dense2_2(x_2)
        x_2 = self.dense2_3(x_2)

        x_3 = self.dense3_1(x_2)
        x_3 = self.dense3_2(x_3)
        x_3 = self.dense3_3(x_3)
        x_3 = self.dense3_4(x_3)
        x_3 = self.dense3_o(x_3)
        
        
        return x_3
    


PlainModel = PlainDNNModel()  


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999)

PlainModel.compile(optimizer=opt, loss='mse')

# %% [markdown]
# ## Loading pre-trained model

# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Datasets_for_magfield/Dataset_4m'
# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss + 1e-20)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az')
if os.getcwd != source_file_model:
  os.chdir(source_file_model)

PlainModel = PlainDNNModel()  
PlainModel.load_weights('PlainDNN_400_796_clean') #PlainDNN_3001_noco


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999 )
#Hmodel = tf.keras.models.load_model('HDNN_300', compile=False)

PlainModel.compile(optimizer=opt, loss=loss_func) # the loss_func is good enough we don't need the loss_func_with_weights

# %%
os.getcwd()
# Out:
# '/home/opc/vantai/Datasets_for_magfield/re_HDNNmodel'

# %%
decay_steps = 40
step = [10, 100, 200, 300]
decay_rate = 0.5

for step in step:
  print(decay_rate**(step/decay_steps))
# Out:
# 0.8408964152537145
# 0.1767766952966369
# 0.03125
# 0.005524271728019903

# %%
y_train.shape
# Out:
# (900000,)

# %%
os.chdir('../')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Data_and_model/Datasets_for_magfield'

# %% [markdown]
# ## Model training

# %%
import pickle
import time
import os
from datetime import datetime
# %load_ext tensorboard

now = datetime.now()

os.mkdir('re_HDNNmodel_IQR_az')

source_file_model = os.path.join('/clusterdata/uqvngu19/scratch/Data_and_model/Datasets_for_magfield/Dataset_4m', 're_HDNNmodel_IQR_az')
if os.getcwd != source_file_model:
  os.chdir(source_file_model)



filepath = os.path.join(os.getcwd(), 'PlainDNN_400_796_clean')

modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, monitor='val_loss', 
                                                     mode='min', verbose=1, save_best_only=True, save_weights_only=True)

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, mode='min', patience=20, min_delta=0.00005)

new_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', verbose=1, patience=10, 
                                              factor=1/10, min_lr=1e-5)

path = "logs/fit/" + now.strftime("%Y/%m/%/d, %H/%M")

#tensorboard = tf.keras.callbacks.TensorBoard(log_dir=path, histogram_freq=1)

st = time.time()

history = PlainModel.fit(s_x_train_scaled, s_y_train_scaled, validation_split=.10, 
                     batch_size=512, epochs=400, callbacks=[earlystopping, modelcheckpoint, new_lr]) 

used_time = time.time() - st

with open('p796_history_400_clean', 'wb') as filename:
  pickle.dump(history.history, filename)

with open('p796_used_time_400_clean', 'wb') as filename:
  pickle.dump(used_time, filename)

#oss: 0.1562 - val_loss: 0.1343
# Out:
# Epoch 1/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.2217 - val_loss: 0.0455
#
# Epoch 00001: val_loss improved from inf to 0.04552, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 2/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0462 - val_loss: 0.0309
#
# Epoch 00002: val_loss improved from 0.04552 to 0.03086, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 3/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0343 - val_loss: 0.0322
#
# Epoch 00003: val_loss did not improve from 0.03086
# Epoch 4/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0286 - val_loss: 0.0268
#
# Epoch 00004: val_loss improved from 0.03086 to 0.02683, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 5/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0264 - val_loss: 0.0209
#
# Epoch 00005: val_loss improved from 0.02683 to 0.02086, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 6/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0228 - val_loss: 0.0166
#
# Epoch 00006: val_loss improved from 0.02086 to 0.01662, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 7/400
# 4560/4560 [==============================] - 35s 8ms/step - loss: 0.0199 - val_loss: 0.0208
#
# Epoch 00007: val_loss did not improve from 0.01662
# Epoch 8/400
# 4560/4560 [==============================] - 34s 8ms/step - loss: 0.0325 - val_loss: 0.0219
#
# Epoch 00008: val_loss did not improve from 0.01662
# Epoch 9/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0197 - val_loss: 0.0420
#
# Epoch 00009: val_loss did not improve from 0.01662
# Epoch 10/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0188 - val_loss: 0.0172
#
# Epoch 00010: val_loss did not improve from 0.01662
# Epoch 11/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0173 - val_loss: 0.0172
#
# Epoch 00011: val_loss did not improve from 0.01662
# Epoch 12/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0156 - val_loss: 0.0165
#
# Epoch 00012: val_loss improved from 0.01662 to 0.01653, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 13/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0151 - val_loss: 0.0138
#
# Epoch 00013: val_loss improved from 0.01653 to 0.01383, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 14/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0138 - val_loss: 0.0120
#
# Epoch 00014: val_loss improved from 0.01383 to 0.01204, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 15/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0128 - val_loss: 0.0127
#
# Epoch 00015: val_loss did not improve from 0.01204
# Epoch 16/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0129 - val_loss: 0.0165
#
# Epoch 00016: val_loss did not improve from 0.01204
# Epoch 17/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0119 - val_loss: 0.0204
#
# Epoch 00017: val_loss did not improve from 0.01204
# Epoch 18/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0118 - val_loss: 0.0138
#
# Epoch 00018: val_loss did not improve from 0.01204
# Epoch 19/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0115 - val_loss: 0.0113
#
# Epoch 00019: val_loss improved from 0.01204 to 0.01128, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 20/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0110 - val_loss: 0.0095
#
# Epoch 00020: val_loss improved from 0.01128 to 0.00949, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 21/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0113 - val_loss: 0.0081
#
# Epoch 00021: val_loss improved from 0.00949 to 0.00810, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 22/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0106 - val_loss: 0.0076
#
# Epoch 00022: val_loss improved from 0.00810 to 0.00756, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 23/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0099 - val_loss: 0.0088
#
# Epoch 00023: val_loss did not improve from 0.00756
# Epoch 24/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0102 - val_loss: 0.0081
#
# Epoch 00024: val_loss did not improve from 0.00756
# Epoch 25/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0094 - val_loss: 0.0099
#
# Epoch 00025: val_loss did not improve from 0.00756
# Epoch 26/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0102 - val_loss: 0.0095
#
# Epoch 00026: val_loss did not improve from 0.00756
# Epoch 27/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0101 - val_loss: 0.0071
#
# Epoch 00027: val_loss improved from 0.00756 to 0.00714, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 28/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0088 - val_loss: 0.0081
#
# Epoch 00028: val_loss did not improve from 0.00714
# Epoch 29/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0093 - val_loss: 0.0110
#
# Epoch 00029: val_loss did not improve from 0.00714
# Epoch 30/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0089 - val_loss: 0.0109
#
# Epoch 00030: val_loss did not improve from 0.00714
# Epoch 31/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0097 - val_loss: 0.0216
#
# Epoch 00031: val_loss did not improve from 0.00714
# Epoch 32/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0180 - val_loss: 0.0126
#
# Epoch 00032: val_loss did not improve from 0.00714
# Epoch 33/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0131 - val_loss: 0.0092
#
# Epoch 00033: val_loss did not improve from 0.00714
# Epoch 34/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0124 - val_loss: 0.0103
#
# Epoch 00034: val_loss did not improve from 0.00714
# Epoch 35/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0098 - val_loss: 0.0250
#
# Epoch 00035: val_loss did not improve from 0.00714
# Epoch 36/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0167 - val_loss: 0.0109
#
# Epoch 00036: val_loss did not improve from 0.00714
# Epoch 37/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0105 - val_loss: 0.0093
#
# Epoch 00037: val_loss did not improve from 0.00714
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 38/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0048 - val_loss: 0.0041
#
# Epoch 00038: val_loss improved from 0.00714 to 0.00405, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 39/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0035 - val_loss: 0.0039
#
# Epoch 00039: val_loss improved from 0.00405 to 0.00385, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 40/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0033 - val_loss: 0.0036
#
# Epoch 00040: val_loss improved from 0.00385 to 0.00358, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 41/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0030 - val_loss: 0.0035
#
# Epoch 00041: val_loss improved from 0.00358 to 0.00352, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 42/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0029 - val_loss: 0.0034
#
# Epoch 00042: val_loss improved from 0.00352 to 0.00341, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 43/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0029 - val_loss: 0.0034
#
# Epoch 00043: val_loss improved from 0.00341 to 0.00339, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 44/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00044: val_loss improved from 0.00339 to 0.00318, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 45/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0027 - val_loss: 0.0032
#
# Epoch 00045: val_loss did not improve from 0.00318
# Epoch 46/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0026 - val_loss: 0.0032
#
# Epoch 00046: val_loss did not improve from 0.00318
# Epoch 47/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0025 - val_loss: 0.0032
#
# Epoch 00047: val_loss did not improve from 0.00318
# Epoch 48/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0025 - val_loss: 0.0030
#
# Epoch 00048: val_loss improved from 0.00318 to 0.00301, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 49/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0024 - val_loss: 0.0031
#
# Epoch 00049: val_loss did not improve from 0.00301
# Epoch 50/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0024 - val_loss: 0.0029
#
# Epoch 00050: val_loss improved from 0.00301 to 0.00290, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 51/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0024 - val_loss: 0.0030
#
# Epoch 00051: val_loss did not improve from 0.00290
# Epoch 52/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0023 - val_loss: 0.0030
#
# Epoch 00052: val_loss did not improve from 0.00290
# Epoch 53/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0022 - val_loss: 0.0030
#
# Epoch 00053: val_loss did not improve from 0.00290
# Epoch 54/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00054: val_loss improved from 0.00290 to 0.00281, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 55/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0022 - val_loss: 0.0029
#
# Epoch 00055: val_loss did not improve from 0.00281
# Epoch 56/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0022 - val_loss: 0.0028
#
# Epoch 00056: val_loss did not improve from 0.00281
# Epoch 57/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00057: val_loss improved from 0.00281 to 0.00279, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 58/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00058: val_loss improved from 0.00279 to 0.00278, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 59/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00059: val_loss improved from 0.00278 to 0.00270, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 60/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0021 - val_loss: 0.0027
#
# Epoch 00060: val_loss did not improve from 0.00270
# Epoch 61/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0020 - val_loss: 0.0031
#
# Epoch 00061: val_loss did not improve from 0.00270
# Epoch 62/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0020 - val_loss: 0.0026
#
# Epoch 00062: val_loss improved from 0.00270 to 0.00264, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 63/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0020 - val_loss: 0.0028
#
# Epoch 00063: val_loss did not improve from 0.00264
# Epoch 64/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0019 - val_loss: 0.0028
#
# Epoch 00064: val_loss did not improve from 0.00264
# Epoch 65/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00065: val_loss improved from 0.00264 to 0.00259, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 66/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00066: val_loss did not improve from 0.00259
# Epoch 67/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0018 - val_loss: 0.0028
#
# Epoch 00067: val_loss did not improve from 0.00259
# Epoch 68/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00068: val_loss did not improve from 0.00259
# Epoch 69/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0018 - val_loss: 0.0027
#
# Epoch 00069: val_loss did not improve from 0.00259
# Epoch 70/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0019 - val_loss: 0.0027
#
# Epoch 00070: val_loss did not improve from 0.00259
# Epoch 71/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0018 - val_loss: 0.0026
#
# Epoch 00071: val_loss improved from 0.00259 to 0.00258, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 72/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0018 - val_loss: 0.0033
#
# Epoch 00072: val_loss did not improve from 0.00258
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 73/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0018 - val_loss: 0.0024
#
# Epoch 00073: val_loss improved from 0.00258 to 0.00241, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 74/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00074: val_loss improved from 0.00241 to 0.00238, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 75/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00075: val_loss did not improve from 0.00238
# Epoch 76/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00076: val_loss did not improve from 0.00238
# Epoch 77/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00077: val_loss did not improve from 0.00238
# Epoch 78/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00078: val_loss did not improve from 0.00238
# Epoch 79/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00079: val_loss did not improve from 0.00238
# Epoch 80/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00080: val_loss did not improve from 0.00238
# Epoch 81/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00081: val_loss did not improve from 0.00238
# Epoch 82/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00082: val_loss did not improve from 0.00238
# Epoch 83/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00083: val_loss did not improve from 0.00238
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 84/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00084: val_loss did not improve from 0.00238
# Epoch 85/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00085: val_loss did not improve from 0.00238
# Epoch 86/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00086: val_loss did not improve from 0.00238
# Epoch 87/400
# 4560/4560 [==============================] - 34s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00087: val_loss did not improve from 0.00238
# Epoch 88/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00088: val_loss did not improve from 0.00238
# Epoch 89/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00089: val_loss did not improve from 0.00238
# Epoch 90/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00090: val_loss did not improve from 0.00238
# Epoch 91/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00091: val_loss improved from 0.00238 to 0.00238, saving model to /scratch/cvl/uqvngu19/Data_and_model/Datasets_for_magfield/Dataset_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 92/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00092: val_loss did not improve from 0.00238
# Epoch 93/400
# 4560/4560 [==============================] - 33s 7ms/step - loss: 0.0014 - val_loss: 0.0024
#
# Epoch 00093: val_loss did not improve from 0.00238
# Epoch 00093: early stopping

# %% [markdown]
# ## History plotting

# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Datasets_for_magfield/Dataset_4m'
source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az')

if os.getcwd() != source_file_model:
  os.chdir(source_file_model)


with open('p796_history_400_clean', 'rb') as filename:
  hist1 = pickle.load(filename)

pdhist1 = pd.DataFrame(hist1)
#pdhist2 = pd.DataFrame(hist2)


#pdhist = pd.concat([pdhist1, pdhist2], axis=0, ignore_index_=True)


pdhist1['loss'].plot(linestyle='--', c='b')
pdhist1['val_loss'].plot(c='r')

plt.legend(loc='upper right', fontsize=16)
plt.grid()
plt.xlim(0, 95)
plt.ylim(0, 0.12)

plt.xlabel('Epochs (EAz)', fontsize=16)
plt.ylabel('Errors', fontsize=16)

#plt.text(170, .05, r"$\hat\alpha = 1.0,$",fontsize=12)
#plt.text(170, .04, r"$\hat\beta = 1.0$",fontsize=12)

#plt.text(310, .05, r"$\hat\alpha = 1.8,$",fontsize=12)
#plt.text(310, .04, r"$\hat\beta = 2.5$",fontsize=12)

#plt.text(410, .05, r"$\hat\alpha = 3.0,$",fontsize=12)
#plt.text(410, .04, r"$\hat\beta = 5.0$",fontsize=12)

#plt.vlines(300, ymin=0, ymax=.12, linestyles='dotted')
#plt.vlines(400, ymin=0, ymax=.12, linestyles='dotted')
# Out:
# Text(0, 0.5, 'Errors')

# %%
PlainModel.summary()
# Out:
# Model: "plain_dnn_model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            multiple                  7960
# _________________________________________________________________
# dense_111 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_112 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_113 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_114 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_115 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_116 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_117 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_118 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_119 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_120 (Dense)            multiple                  2391
# =================================================================
# Total params: 5,720,059
# Trainable params: 5,720,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model testing

# %%
# Predicting the results
s_y_predicted_scaled = PlainModel.predict(s_x_test_scaled)

# Predicting the results
#y_predicted = PlainModel.predict(x_test)

# %%
out_y_predicted_scaled = PlainModel.predict(out_x_scaled)

# %%
# Testing the model
from sklearn.metrics import r2_score, mean_squared_error
r2_score(s_y_test_scaled, s_y_predicted_scaled)

#r2_score(s_y_test_scaled[:, 0], s_y_predicted_scaled[:, 0])
# Out:
# 0.9972570547325703

# %%
import scipy.stats as ss


ss.pearsonr(np.squeeze(s_y_test_scaled), np.squeeze(s_y_predicted_scaled))
# Out:
# (0.998627734044102, 0.0)

# %%
y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled).astype(np.float32)
y_test = y_sScaler.inverse_transform(s_y_test_scaled).astype(np.float32)

# %%
np.round(x_sScaler.inverse_transform(s_x_test_scaled)[10:20], decimals=2)
# Out:
# array([[ 38.92,  32.51,   9.27, 146.87,   2.7 ,  25.2 ,   0.  ,   1.  ,
#           0.  ],
#        [ 38.56,   5.02,  45.45, 134.21,   2.59, -28.47,   0.  ,   1.  ,
#           0.  ],
#        [ 26.72,  14.72,  42.47, 107.04,   5.29, -39.49,   1.  ,   0.  ,
#           0.  ],
#        [ 13.96,   8.54,  49.61,  44.22,   3.15, -68.71,   0.  ,   1.  ,
#           0.  ],
#        [ 13.82,  24.22,  48.26, 142.38,   3.49,  28.67,   0.  ,   1.  ,
#           0.  ],
#        [ 17.24,  25.08,  29.25,  93.8 ,   5.1 , -45.96,   1.  ,   0.  ,
#           0.  ],
#        [  9.55,  29.74,  15.79,  53.74,   4.71, -44.93,   0.  ,   0.  ,
#           1.  ],
#        [ 24.19,  30.24,   8.32,   6.82,   0.85, -54.14,   0.  ,   1.  ,
#           0.  ],
#        [ 22.67,  38.71,  32.06, 135.13,   1.84,  10.67,   0.  ,   0.  ,
#           1.  ],
#        [ 15.12,   7.34,  20.46, 105.78,   1.14,  67.21,   1.  ,   0.  ,
#           0.  ]])

# %%
np.round(y_sScaler.inverse_transform(s_y_predicted_scaled)[0:10], decimals=2)
# Out:
# array([[-1208.87],
#        [   54.91],
#        [   -9.11],
#        [   33.22],
#        [  -21.53],
#        [ 1203.95],
#        [ -126.48],
#        [   -7.42],
#        [  -36.22],
#        [   14.6 ]], dtype=float32)

# %%
import numpy as np
np.round(y_test[0:10], decimals=2)
# Out:
# array([-1239.19,    57.32,    -7.03,    31.13,   -24.12,  1211.98,
#         -130.48,   -12.59,   -33.4 ,     9.95])

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_test = y_sScaler.inverse_transform(s_y_test_scaled)

np.sqrt(mean_squared_error(y_test, y_sScaler.inverse_transform(s_y_predicted_scaled)))
# Out:
# 58.21643366812288

# %%
58.22/np.subtract(*np.percentile(y_test, [5, 95]))
# Out:
# -0.013740376009194678

# %%
interq_955 = np.subtract(*np.percentile(y_test, [95, 5]))
print(interq_955)
# Out:
# 4237.147510449553

# %%
import matplotlib.pyplot as plt

y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled)
a, b = np.polyfit(np.squeeze(y_test), np.squeeze(y_pred), 1)
plt.scatter(y_test, y_pred)
plt.plot(y_test, a*y_test+b, color='r')
plt.xlabel('Ground truth field (A/m) (EAz)', fontsize=16)
plt.ylabel('Predicted field (A/m)', fontsize=16)
plt.grid('on')

# %%
abs((y_test - y_pred))*100/interq_955
# Out:
# array([[0.7156373 ],
#        [0.05698345],
#        [0.04915408],
#        ...,
#        [0.31554355],
#        [0.14978064],
#        [0.38562342]])

# %%
interq_955 = np.subtract(*np.percentile(y_test, [95, 5]))
print(interq_955)
# Out:
# 4231.928351199376

# %%
# Plotting pairs
# Not normalized
import seaborn as sns
index_ = 1

#vmin = np.min(s_y_test_scaled[:, index_])
#vmax = np.max(s_y_test_scaled[:, index_])
cmap = 'YlGnBu'
 # 0 for axial, 1 for azimuthal and 2 for radial components

height = [0.00148, 0.788, 0.00395]
low = [-0.000227, -0.12, -0.000588]
plt.figure(figsize=(10, 14))

interq_955 = np.subtract(*np.percentile(y_test, [95, 5]))
errors = abs((y_test - y_pred))*100/interq_955 


# errors = (s_y_predicted_scaled[:, index_+1].reshape(400000,-1)-s_y_test_scaled[:, index_+1].reshape(400000,-1))*100/(
#     np.max(s_y_test_scaled[:, index_+1]) - np.min(s_y_test_scaled[:, index_+1]))



plt.subplot(342)
mean = np.mean(errors)
std = np.std(errors)

print('mean: {}, std: {}'.format(mean, std))

sns.distplot(errors, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
#sns.kdeplot(data=errors, fill=True)
plt.xlim(-5, 5)
plt.text(-7, -0.25, 'ND (%) (EAz)', fontsize=16)
#plt.text(-20, 1.6*low[index_+1], 'j) Azimuthal component', fontsize=12)
# #plt.xlabel('b) Azimuthal component', fontsize=12)
plt.ylabel('Kernel density estimation', fontsize=16)
plt.text(-9, 1.53, '\u03BC = {:2.2}, \u03C3 = {:0.3}'.format(mean, std), fontsize=16) # height index_ .2 for axial; = 6.5 for azimuthal and .42 for radial
# #plt.tight_layout(rect=(0., 0., 1, 1))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1., hspace=None)
# Out:
# mean: 0.4270358570317295, std: 1.3059052078999998
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
