# %% [markdown]
# # Plain-DNN for magnetic field

# %% [markdown]
# ## Navigating to the working directory containing the datasets and model

# %% [markdown]
# # Technical issues: Swap radial component to the azimuthal one as there was a mistake on the index

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.12

# %% [markdown]
# ## Checking the current working GPU

# %%
# !nvidia-smi
# Out:
# Mon Mar 14 15:10:09 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 450.51.05    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:01:00.0 Off |                    0 |
# | N/A   56C    P0    29W /  70W |  14948MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2823      G   /usr/bin/X                         27MiB |
# |    0   N/A  N/A     33890      C   ...u19/miniconda3/bin/python      665MiB |
# |    0   N/A  N/A     57448      C   ...u19/miniconda3/bin/python    14253MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Loading the datasets and doing feature engineering

# %%
# Loading data

import pickle
import os
import numpy as np 
# source_file_data_111 = '/content/drive/My Drive/part_C_all_1'
# os.chdir(source_file_data_111)

# with open('all_1_para', 'rb') as file_para:
#     para = pickle.load(file_para)
    
# with open('all_1_output_field', 'rb') as file_out:
#     output_field = pickle.load(file_out)
source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'
os.chdir(source_file)

with open('para_cone_4m', 'rb') as file_para:
    para = np.array(pickle.load(file_para))
    
with open('output_field_cone_4m', 'rb') as file_out:
    output_field = np.array(pickle.load(file_out))


# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
mask_c = (para[:, 6] != 1.)

# %%
out_c = np.unique(output_field[mask_c])
para_c = para[mask_c]

# %%
#output_field_np = np.array(output_field)

output_field_np
# Out:
# array([[-1.02575151e+00, -4.89685924e-01,  2.92794212e-01],
#        [-5.73160570e+02,  5.04197703e+02, -1.17510070e+02],
#        [ 3.72303466e+01, -5.11381807e+01,  9.82458572e+01],
#        ...,
#        [ 3.92974320e+02, -2.96509763e+03,  7.35521515e+01],
#        [-1.62606075e+01, -5.38410642e+01, -1.38220779e+02],
#        [ 3.37150935e+02,  0.00000000e+00, -6.50053134e+01]])

# %% [markdown]
# ## Cleaning data

# %%
# cleaning data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle

random.seed(123)

mask_c = (para[:, 6] != 1.)

para_np = para[mask_c]
output_field_np = output_field[mask_c]

index = 1

q1, q3 = np.percentile(output_field_np[:, index], [25, 75])

upper = q3 + 1.5*(q3-q1)
lower = q1 - 1.5*(q3-q1)

mask = (output_field_np[:, index] > lower)*(output_field_np[:, index] < upper)

mask_index = np.where(mask)[0]

clean_1 = output_field_np[:, index][mask]

para_1 = para_np[mask_index][:, :5]

# %%
print(para_1[0], para[0])
#para[0]
# Out:
# [  0.15581025   7.09777384  61.08626455   5.66239955 -58.84496476] [  0.15581025   7.09777384  61.08626455   5.66239955 -58.84496476
#    1.           0.        ]

# %%
import seaborn as sns
sns.distplot(clean_1, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.hist(clean_1)
# plt.hist(output_field_np[:, 0])
#sns.distplot(output_field_np[:, 0], kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# (array([ 26452.,  34325.,  49815.,  84734., 552844., 393582.,  83764.,
#          48846.,  34879.,  26641.]),
#  array([-2263.80860387, -1810.23360267, -1356.65860148,  -903.08360028,
#          -449.50859909,     4.06640211,   457.6414033 ,   911.2164045 ,
#          1364.79140569,  1818.36640689,  2271.94140808]),
#  <BarContainer object of 10 artists>)

# %%
# mask = np.argwhere(output_field_np <= q3)
# mask.shape

from matplotlib import pyplot as plt

plt.hist(para_1[:,0])

#np.unique(output_field_np[:, 0], return_counts=True)
# Out:
# (array([192758., 184373., 174287., 162852., 148559., 132915., 114654.,
#          95327.,  75527.,  54630.]),
#  array([0.0872687 , 0.21816807, 0.34906743, 0.4799668 , 0.61086616,
#         0.74176552, 0.87266489, 1.00356425, 1.13446362, 1.26536298,
#         1.39626235]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(output_field_np)
para_1.shape
# Out:
# (1335882, 5)

# %% [markdown]
# ## Feature engineering for clean data

# %%
# Feature engineering for clean datasets
# Feature engineering

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle

random.seed(123)

para_np = para_1 #np.array(para)
output_field_np = clean_1 #np.array(output_field)

#q1, q3 = np.percentile(output_field_np, [5, 95])

x_train, x_test, y_train, y_test = train_test_split(para_np, output_field_np, test_size=.10, shuffle=True)

x_sScaler = StandardScaler()
x_sScaler.fit(x_train)
s_x_train_scaled = x_sScaler.transform(x_train)
s_x_test_scaled = x_sScaler.transform(x_test)

y_sScaler = StandardScaler()
y_sScaler.fit(y_train.reshape(-1, 1))
s_y_train_scaled = y_sScaler.transform(y_train.reshape(-1, 1))
s_y_test_scaled = y_sScaler.transform(y_test.reshape(-1, 1))


# # Saving training, testing and scalers data


with open('re_s_x_train_scaled_az_co', 'wb') as filename: # co - correct
  pickle.dump(s_x_train_scaled, filename)

with open('re_s_y_train_scaled_az_co', 'wb') as filename:
  pickle.dump(s_y_train_scaled, filename)

with open('re_s_x_test_scaled_az_co', 'wb') as filename:
  pickle.dump(s_x_test_scaled, filename)

with open('re_s_y_test_scaled_az_co', 'wb') as filename:
  pickle.dump(s_y_test_scaled, filename)

with open('re_x_sScaler_az_co', 'wb') as filename:
  pickle.dump(x_sScaler, filename)

with open('re_y_sScaler_az_co', 'wb') as filename:
  pickle.dump(y_sScaler, filename)

# %%
s_x_train_scaled
# Out:
# (array([[     0., 145325., 190823., 179074., 165579., 147975., 127527.,
#          105669.,  82416.,  57905.],
#         [     0., 141252., 201636., 181940., 159267., 139529., 122455.,
#          107712.,  95175.,  53327.],
#         [ 83687., 101219., 121108., 139095., 153840., 165668., 175383.,
#          183250.,  79043.,      0.],
#         [ 33574., 156202., 135613., 139927., 177793., 154318., 135671.,
#          139738., 129457.,      0.],
#         [     0., 171057., 176776., 161316., 144159., 133085., 134786.,
#          145776., 135338.,      0.]]),
#  array([-2.06794673, -1.63625907, -1.20457141, -0.77288375, -0.3411961 ,
#          0.09049156,  0.52217922,  0.95386688,  1.38555454,  1.8172422 ,
#          2.24892986]),
#  <a list of 5 BarContainer objects>)

# %% [markdown]
# ## Loading ready processed datasets

# %%
import pickle
import os

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'

os.chdir(source_file)

with open('re_s_x_train_scaled_az_co', 'rb') as filename:
  s_x_train_scaled = pickle.load(filename)

with open('re_s_y_train_scaled_az_co', 'rb') as filename:
  s_y_train_scaled = pickle.load(filename)

with open('re_s_x_test_scaled_az_co', 'rb') as filename:
  s_x_test_scaled = pickle.load(filename)

with open('re_s_y_test_scaled_az_co', 'rb') as filename:
  s_y_test_scaled = pickle.load(filename)

with open('re_x_sScaler_az_co', 'rb') as filename:
  x_sScaler = pickle.load(filename)

with open('re_y_sScaler_az_co', 'rb') as filename:
  y_sScaler = pickle.load(filename)

# importing data for out of training intervals

# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
import numpy as np
min_ = np.min(s_y_train_scaled)
max_ = np.max(s_y_train_scaled)

out_min_ = np.min(out_y_scaled)
out_max_ = np.max(out_y_scaled)
print(f'Field interval for the training data is: [{min_}, {max_}]')
print(f'Field interval for the out of training intervals is: [{out_min_}, {out_max_}]')
# Out:
# Field interval for the training data is: [-23.610358434445427, 23.999540757658966]
# Field interval for the out of training intervals is: [-2.3426246433144176, 2.2994854937939446]

# %%
with open('out_para_200k', 'rb') as filename:
  out_para_scaled = pickle.load(filename)

# %%
x_train.shape
# Out:
# (1372003, 9)

# %% [markdown]
# ## PlainDNN model development

# %%
# Plain DNN model


import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation


# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

class PlainDNNModel(tf.keras.Model):
    def __init__(self):
        
        super(PlainDNNModel, self).__init__()
        
        self.dense1_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense2_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense3_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_4 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_o = tf.keras.layers.Dense(1)

        
    def call(self, inputs):
        
        x_1 = self.dense1_1(inputs)
        x_1 = self.dense1_2(x_1)
        x_1 = self.dense1_3(x_1)

        
        x_2 = self.dense2_1(x_1)
        x_2 = self.dense2_2(x_2)
        x_2 = self.dense2_3(x_2)

        x_3 = self.dense3_1(x_2)
        x_3 = self.dense3_2(x_3)
        x_3 = self.dense3_3(x_3)
        x_3 = self.dense3_4(x_3)
        x_3 = self.dense3_o(x_3)
        
        
        return x_3
    


PlainModel = PlainDNNModel()  


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999)

PlainModel.compile(optimizer=opt, loss='mse')

# %% [markdown]
# ## Loading pre-trained model

# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation

#source_file = '/content/drive/My Drive/Data_and_model/Datasets_for_magfield'
# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss + 1e-20)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az_co')
if os.getcwd != source_file_model:
  os.chdir(source_file_model)

PlainModel = PlainDNNModel()  
PlainModel.load_weights('PlainDNN_400_796_clean') #PlainDNN_3001_noco


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999 )
#Hmodel = tf.keras.models.load_model('HDNN_300', compile=False)

PlainModel.compile(optimizer=opt, loss='mse') # the loss_func is good enough we don't need the loss_func_with_weights

# %%
os.getcwd()
# Out:
# '/home/opc/vantai/Datasets_for_magfield/re_HDNNmodel'

# %%
decay_steps = 40
step = [10, 100, 200, 300]
decay_rate = 0.5

for step in step:
  print(decay_rate**(step/decay_steps))
# Out:
# 0.8408964152537145
# 0.1767766952966369
# 0.03125
# 0.005524271728019903

# %%
y_train.shape
# Out:
# (900000,)

# %% [markdown]
# ## Model training

# %%
import pickle
import time
import os
from datetime import datetime
# %load_ext tensorboard

now = datetime.now()
#os.mkdir('re_HDNNmodel_IQR_az_co')

source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az_co')
if os.getcwd != source_file_model:
  os.chdir(source_file_model)



filepath = os.path.join(os.getcwd(), 'PlainDNN_400_796_clean')

modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, monitor='val_loss', 
                                                     mode='min', verbose=1, save_best_only=True, save_weights_only=True)

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, mode='min', patience=20, min_delta=0.00005)

new_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', verbose=1, patience=10, 
                                              factor=1/10, min_lr=1e-5)

path = "logs/fit/" + now.strftime("%Y/%m/%/d, %H/%M")

#tensorboard = tf.keras.callbacks.TensorBoard(log_dir=path, histogram_freq=1)

st = time.time()

history = PlainModel.fit(s_x_train_scaled, s_y_train_scaled, validation_split=.10, 
                     batch_size=512, epochs=400, callbacks=[earlystopping, modelcheckpoint, new_lr]) #[earlystopping, modelcheckpoint, new_lr]

used_time = time.time() - st

with open('p796_history_400_clean', 'wb') as filename:
  pickle.dump(history.history, filename)

with open('p796_used_time_400_clean', 'wb') as filename:
  pickle.dump(used_time, filename)

#oss: 0.1562 - val_loss: 0.1343
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Epoch 1/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.1373 - val_loss: 0.0224
#
# Epoch 00001: val_loss improved from inf to 0.02243, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 2/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0244 - val_loss: 0.0320
#
# Epoch 00002: val_loss did not improve from 0.02243
# Epoch 3/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0195 - val_loss: 0.0275
#
# Epoch 00003: val_loss did not improve from 0.02243
# Epoch 4/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0161 - val_loss: 0.0228
#
# Epoch 00004: val_loss did not improve from 0.02243
# Epoch 5/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0132 - val_loss: 0.0104
#
# Epoch 00005: val_loss improved from 0.02243 to 0.01043, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 6/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0133 - val_loss: 0.0102
#
# Epoch 00006: val_loss improved from 0.01043 to 0.01021, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 7/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0109 - val_loss: 0.0098
#
# Epoch 00007: val_loss improved from 0.01021 to 0.00976, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 8/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0117 - val_loss: 0.0161
#
# Epoch 00008: val_loss did not improve from 0.00976
# Epoch 9/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0099 - val_loss: 0.0082
#
# Epoch 00009: val_loss improved from 0.00976 to 0.00822, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 10/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0090 - val_loss: 0.0071
#
# Epoch 00010: val_loss improved from 0.00822 to 0.00710, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 11/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0095 - val_loss: 0.0067
#
# Epoch 00011: val_loss improved from 0.00710 to 0.00674, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 12/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0073 - val_loss: 0.0043
#
# Epoch 00012: val_loss improved from 0.00674 to 0.00427, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 13/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0070 - val_loss: 0.0067
#
# Epoch 00013: val_loss did not improve from 0.00427
# Epoch 14/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0083 - val_loss: 0.0062
#
# Epoch 00014: val_loss did not improve from 0.00427
# Epoch 15/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0066 - val_loss: 0.0071
#
# Epoch 00015: val_loss did not improve from 0.00427
# Epoch 16/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0064 - val_loss: 0.0060
#
# Epoch 00016: val_loss did not improve from 0.00427
# Epoch 17/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0060 - val_loss: 0.0041
#
# Epoch 00017: val_loss improved from 0.00427 to 0.00407, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 18/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0052 - val_loss: 0.0093
#
# Epoch 00018: val_loss did not improve from 0.00407
# Epoch 19/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0058 - val_loss: 0.0041
#
# Epoch 00019: val_loss improved from 0.00407 to 0.00406, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 20/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0048 - val_loss: 0.0100
#
# Epoch 00020: val_loss did not improve from 0.00406
# Epoch 21/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0069 - val_loss: 0.0040
#
# Epoch 00021: val_loss improved from 0.00406 to 0.00399, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 22/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0053 - val_loss: 0.0080
#
# Epoch 00022: val_loss did not improve from 0.00399
# Epoch 23/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0055 - val_loss: 0.0084
#
# Epoch 00023: val_loss did not improve from 0.00399
# Epoch 24/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0050 - val_loss: 0.0061
#
# Epoch 00024: val_loss did not improve from 0.00399
# Epoch 25/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0054 - val_loss: 0.0076
#
# Epoch 00025: val_loss did not improve from 0.00399
# Epoch 26/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0063 - val_loss: 0.0055
#
# Epoch 00026: val_loss did not improve from 0.00399
# Epoch 27/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0056 - val_loss: 0.0032
#
# Epoch 00027: val_loss improved from 0.00399 to 0.00317, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 28/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0043 - val_loss: 0.0027
#
# Epoch 00028: val_loss improved from 0.00317 to 0.00272, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 29/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0045 - val_loss: 0.0048
#
# Epoch 00029: val_loss did not improve from 0.00272
# Epoch 30/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0044 - val_loss: 0.0072
#
# Epoch 00030: val_loss did not improve from 0.00272
# Epoch 31/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0041 - val_loss: 0.0049
#
# Epoch 00031: val_loss did not improve from 0.00272
# Epoch 32/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0040 - val_loss: 0.0037
#
# Epoch 00032: val_loss did not improve from 0.00272
# Epoch 33/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0036 - val_loss: 0.0035
#
# Epoch 00033: val_loss did not improve from 0.00272
# Epoch 34/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0035 - val_loss: 0.0030
#
# Epoch 00034: val_loss did not improve from 0.00272
# Epoch 35/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0049 - val_loss: 0.0049
#
# Epoch 00035: val_loss did not improve from 0.00272
# Epoch 36/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0042 - val_loss: 0.0042
#
# Epoch 00036: val_loss did not improve from 0.00272
# Epoch 37/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0039 - val_loss: 0.0017
#
# Epoch 00037: val_loss improved from 0.00272 to 0.00174, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 38/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0030 - val_loss: 0.0032
#
# Epoch 00038: val_loss did not improve from 0.00174
# Epoch 39/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0035 - val_loss: 0.0047
#
# Epoch 00039: val_loss did not improve from 0.00174
# Epoch 40/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0031 - val_loss: 0.0044
#
# Epoch 00040: val_loss did not improve from 0.00174
# Epoch 41/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0035 - val_loss: 0.0038
#
# Epoch 00041: val_loss did not improve from 0.00174
# Epoch 42/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0032 - val_loss: 0.0028
#
# Epoch 00042: val_loss did not improve from 0.00174
# Epoch 43/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0027 - val_loss: 0.0047
#
# Epoch 00043: val_loss did not improve from 0.00174
# Epoch 44/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0034 - val_loss: 0.0039
#
# Epoch 00044: val_loss did not improve from 0.00174
# Epoch 45/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0026 - val_loss: 0.0025
#
# Epoch 00045: val_loss did not improve from 0.00174
# Epoch 46/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 0.0027 - val_loss: 0.0022
#
# Epoch 00046: val_loss did not improve from 0.00174
# Epoch 47/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 0.0029 - val_loss: 0.0059
#
# Epoch 00047: val_loss did not improve from 0.00174
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 48/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 8.4047e-04 - val_loss: 5.7518e-04
#
# Epoch 00048: val_loss improved from 0.00174 to 0.00058, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 49/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 4.8339e-04 - val_loss: 5.0655e-04
#
# Epoch 00049: val_loss improved from 0.00058 to 0.00051, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 50/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 4.3779e-04 - val_loss: 4.7750e-04
#
# Epoch 00050: val_loss improved from 0.00051 to 0.00048, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 51/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 4.1605e-04 - val_loss: 7.9346e-04
#
# Epoch 00051: val_loss did not improve from 0.00048
# Epoch 52/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 4.4561e-04 - val_loss: 6.4224e-04
#
# Epoch 00052: val_loss did not improve from 0.00048
# Epoch 53/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.8108e-04 - val_loss: 4.6004e-04
#
# Epoch 00053: val_loss improved from 0.00048 to 0.00046, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 54/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.7754e-04 - val_loss: 4.3520e-04
#
# Epoch 00054: val_loss improved from 0.00046 to 0.00044, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 55/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.9913e-04 - val_loss: 4.4211e-04
#
# Epoch 00055: val_loss did not improve from 0.00044
# Epoch 56/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.7985e-04 - val_loss: 4.6624e-04
#
# Epoch 00056: val_loss did not improve from 0.00044
# Epoch 57/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.5518e-04 - val_loss: 4.4239e-04
#
# Epoch 00057: val_loss did not improve from 0.00044
# Epoch 58/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.1379e-04 - val_loss: 5.5179e-04
#
# Epoch 00058: val_loss did not improve from 0.00044
# Epoch 59/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.9971e-04 - val_loss: 5.5489e-04
#
# Epoch 00059: val_loss did not improve from 0.00044
# Epoch 60/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 2.9391e-04 - val_loss: 3.6674e-04
#
# Epoch 00060: val_loss improved from 0.00044 to 0.00037, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 61/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.6077e-04 - val_loss: 5.3970e-04
#
# Epoch 00061: val_loss did not improve from 0.00037
# Epoch 62/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.7111e-04 - val_loss: 3.8368e-04
#
# Epoch 00062: val_loss did not improve from 0.00037
# Epoch 63/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 3.4189e-04 - val_loss: 3.4346e-04
#
# Epoch 00063: val_loss improved from 0.00037 to 0.00034, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 64/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 2.8921e-04 - val_loss: 4.2559e-04
#
# Epoch 00064: val_loss did not improve from 0.00034
# Epoch 65/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.3047e-04 - val_loss: 5.5347e-04
#
# Epoch 00065: val_loss did not improve from 0.00034
# Epoch 66/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 4.2384e-04 - val_loss: 4.3064e-04
#
# Epoch 00066: val_loss did not improve from 0.00034
# Epoch 67/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 2.8092e-04 - val_loss: 8.7443e-04
#
# Epoch 00067: val_loss did not improve from 0.00034
# Epoch 68/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.5676e-04 - val_loss: 3.2291e-04
#
# Epoch 00068: val_loss improved from 0.00034 to 0.00032, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 69/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.1198e-04 - val_loss: 3.3821e-04
#
# Epoch 00069: val_loss did not improve from 0.00032
# Epoch 70/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.2325e-04 - val_loss: 4.0196e-04
#
# Epoch 00070: val_loss did not improve from 0.00032
# Epoch 71/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 2.6671e-04 - val_loss: 3.7948e-04
#
# Epoch 00071: val_loss did not improve from 0.00032
# Epoch 72/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.2098e-04 - val_loss: 4.8720e-04
#
# Epoch 00072: val_loss did not improve from 0.00032
# Epoch 73/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 3.7480e-04 - val_loss: 4.0491e-04
#
# Epoch 00073: val_loss did not improve from 0.00032
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 74/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.9611e-04 - val_loss: 2.7084e-04
#
# Epoch 00074: val_loss improved from 0.00032 to 0.00027, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 75/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6517e-04 - val_loss: 2.6619e-04
#
# Epoch 00075: val_loss improved from 0.00027 to 0.00027, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 76/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 1.8118e-04 - val_loss: 2.6687e-04
#
# Epoch 00076: val_loss did not improve from 0.00027
# Epoch 77/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7239e-04 - val_loss: 2.6409e-04
#
# Epoch 00077: val_loss improved from 0.00027 to 0.00026, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 78/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7612e-04 - val_loss: 2.6636e-04
#
# Epoch 00078: val_loss did not improve from 0.00026
# Epoch 79/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7480e-04 - val_loss: 2.6601e-04
#
# Epoch 00079: val_loss did not improve from 0.00026
# Epoch 80/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6879e-04 - val_loss: 2.7238e-04
#
# Epoch 00080: val_loss did not improve from 0.00026
# Epoch 81/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7867e-04 - val_loss: 2.6653e-04
#
# Epoch 00081: val_loss did not improve from 0.00026
# Epoch 82/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7104e-04 - val_loss: 2.7954e-04
#
# Epoch 00082: val_loss did not improve from 0.00026
# Epoch 83/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7078e-04 - val_loss: 2.5804e-04
#
# Epoch 00083: val_loss improved from 0.00026 to 0.00026, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 84/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6429e-04 - val_loss: 2.6591e-04
#
# Epoch 00084: val_loss did not improve from 0.00026
# Epoch 85/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7028e-04 - val_loss: 2.6114e-04
#
# Epoch 00085: val_loss did not improve from 0.00026
# Epoch 86/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6347e-04 - val_loss: 2.5475e-04
#
# Epoch 00086: val_loss improved from 0.00026 to 0.00025, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 87/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6697e-04 - val_loss: 2.5563e-04
#
# Epoch 00087: val_loss did not improve from 0.00025
# Epoch 88/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6594e-04 - val_loss: 2.5583e-04
#
# Epoch 00088: val_loss did not improve from 0.00025
# Epoch 89/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6781e-04 - val_loss: 2.6334e-04
#
# Epoch 00089: val_loss did not improve from 0.00025
# Epoch 90/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 1.7882e-04 - val_loss: 2.5460e-04
#
# Epoch 00090: val_loss improved from 0.00025 to 0.00025, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 91/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.6543e-04 - val_loss: 2.5736e-04
#
# Epoch 00091: val_loss did not improve from 0.00025
# Epoch 92/400
# 2114/2114 [==============================] - 16s 8ms/step - loss: 1.7249e-04 - val_loss: 2.5412e-04
#
# Epoch 00092: val_loss improved from 0.00025 to 0.00025, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 93/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 1.5915e-04 - val_loss: 2.5305e-04
#
# Epoch 00093: val_loss improved from 0.00025 to 0.00025, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az_co/PlainDNN_400_796_clean
# Epoch 94/400
# 2114/2114 [==============================] - 17s 8ms/step - loss: 1.6031e-04 - val_loss: 2.6400e-04
#
# Epoch 00094: val_loss did not improve from 0.00025
# Epoch 00094: early stopping

# %% [markdown]
# ## History plotting

# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'
source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az_co')

if os.getcwd() != source_file_model:
  os.chdir(source_file_model)


with open('p796_history_400_clean', 'rb') as filename:
  hist1 = pickle.load(filename)

pdhist1 = pd.DataFrame(hist1)
#pdhist2 = pd.DataFrame(hist2)


#pdhist = pd.concat([pdhist1, pdhist2], axis=0, ignore_index_=True)


pdhist1['loss'].plot(linestyle='--', c='b')
pdhist1['val_loss'].plot(c='r')

plt.legend(loc='upper right', fontsize=16)
plt.grid()
plt.xlim(0, 96)
plt.ylim(0, 0.12)

plt.xlabel('Epochs (CAz)', fontsize=16)
plt.ylabel('Errors', fontsize=16)

#plt.text(170, .05, r"$\hat\alpha = 1.0,$",fontsize=12)
#plt.text(170, .04, r"$\hat\beta = 1.0$",fontsize=12)

#plt.text(310, .05, r"$\hat\alpha = 1.8,$",fontsize=12)
#plt.text(310, .04, r"$\hat\beta = 2.5$",fontsize=12)

#plt.text(410, .05, r"$\hat\alpha = 3.0,$",fontsize=12)
#plt.text(410, .04, r"$\hat\beta = 5.0$",fontsize=12)

#plt.vlines(300, ymin=0, ymax=.12, linestyles='dotted')
#plt.vlines(400, ymin=0, ymax=.12, linestyles='dotted')
# Out:
# Text(0, 0.5, 'Errors')

# %%
PlainModel.summary()
# Out:
# Model: "plain_dnn_model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            multiple                  7960
# _________________________________________________________________
# dense_111 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_112 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_113 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_114 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_115 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_116 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_117 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_118 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_119 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_120 (Dense)            multiple                  2391
# =================================================================
# Total params: 5,720,059
# Trainable params: 5,720,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model testing

# %%
# Predicting the results
s_y_predicted_scaled = PlainModel.predict(s_x_test_scaled)

# Predicting the results
#y_predicted = PlainModel.predict(x_test)

# %%
out_y_predicted_scaled = PlainModel.predict(out_x_scaled)

# %%
# Testing the model
from sklearn.metrics import r2_score, mean_squared_error
r2_score(s_y_test_scaled, s_y_predicted_scaled)

#r2_score(s_y_test_scaled[:, 0], s_y_predicted_scaled[:, 0])
# Out:
# 0.9997275921172284

# %%
import scipy.stats as ss


ss.pearsonr(np.squeeze(s_y_test_scaled), np.squeeze(s_y_predicted_scaled))
# Out:
# (0.9998613132520849, 0.0)

# %%
y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled).astype(np.float32)
y_test = y_sScaler.inverse_transform(s_y_test_scaled).astype(np.float32)

# %%
print(y_pred[10:20])
print(y_test[10:20])
# Out:
# [[-2.0057660e+03]
#  [ 2.3064914e+00]
#  [ 6.6146429e+02]
#  [ 2.3401245e-02]
#  [ 3.5997013e+01]
#  [-3.3428097e+00]
#  [ 2.8414011e+02]
#  [ 5.7062115e+01]
#  [ 2.3401245e-02]
#  [ 1.2015660e+03]]
# [[-1.9660837e+03]
#  [ 2.3654473e+00]
#  [ 6.6624017e+02]
#  [ 8.5192609e-01]
#  [ 3.4141193e+01]
#  [-2.8810151e+00]
#  [ 2.8369312e+02]
#  [ 6.3077194e+01]
#  [ 1.6369075e-01]
#  [ 1.2053525e+03]]

# %%
from sklearn.metrics import r2_score, mean_squared_error

np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 11.22335

# %%
11.22335/np.subtract(*np.percentile(y_test, [5, 95]))
# Out:
# -0.004312910902905769

# %%
np.subtract(*np.percentile(y_test, [5, 95]))
# Out:
# -2602.2679931640623

# %%
import matplotlib.pyplot as plt 

y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled)
a, b = np.polyfit(np.squeeze(y_test), np.squeeze(y_pred), 1)
plt.scatter(y_test, y_pred)
plt.plot(y_test, a*y_test+b, color='r')
plt.xlabel('Ground truth field (A/m) (CAz)', fontsize=16)
plt.ylabel('Predicted field (A/m)', fontsize=16)
plt.grid('on')
# CAz ----> Azimuthal component of Cone

# %%
with open('out_para_cone_dataset', 'rb') as filename:
  out_x_scaled = pickle.load(filename)

with open('out_H_cone_dataset', 'rb') as filename:
  out_y_scaled = pickle.load(filename)

# %%
x = x_sScaler.transform(out_x_scaled)
y = y_sScaler.transform(np.array(out_y_scaled)[:, 2].reshape(-1, 1))

# %%
np.array(out_x_scaled).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65036579a405> in <module>
# ----> 1 np.array(out_x_scaled).shape
#
# NameError: name 'np' is not defined

# %%
y_pred - y_test
# Out:
# array([[-1.2627349 ],
#        [ 7.484314  ],
#        [ 2.5948982 ],
#        ...,
#        [ 4.2545166 ],
#        [ 0.5329437 ],
#        [ 0.35831833]], dtype=float32)

# %%
# Plotting pairs
# Not normalized
import seaborn as sns
import matplotlib.pyplot as plt 
index_ = 0

#vmin = np.min(s_y_test_scaled[:, index_])
#vmax = np.max(s_y_test_scaled[:, index_])
cmap = 'YlGnBu'
 # 0 for axial, 1 for azimuthal and 2 for radial components

height = [0.00148, 0.788, 0.00395]
low = [-0.000227, -0.12, -0.000588]
plt.figure(figsize=(10, 14))

interq_955 = np.subtract(*np.percentile(y_test, [95, 5]))
errors = abs(y_pred - y_test)*100/interq_955


# errors = (s_y_predicted_scaled[:, index_+1].reshape(400000,-1)-s_y_test_scaled[:, index_+1].reshape(400000,-1))*100/(
#     np.max(s_y_test_scaled[:, index_+1]) - np.min(s_y_test_scaled[:, index_+1]))



plt.subplot(342)
mean = np.mean(errors)
std = np.std(errors)

print('mean: {}, std: {}'.format(mean, std))

sns.distplot(errors, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
#sns.kdeplot(data=errors, fill=True)
plt.xlim(-5, 5)
plt.text(-7, -0.6, 'ND (%) (CAz)', fontsize=16)
#plt.text(-20, 1.6*low[index_+1], 'j) Azimuthal component', fontsize=12)
# #plt.xlabel('b) Azimuthal component', fontsize=12)
plt.ylabel('Kernel density estimation', fontsize=16)
plt.text(-9, 4.0, '\u03BC = {:2.2}, \u03C3 = {:0.3}'.format(mean, std), fontsize=16) # height index_ .2 for axial; = 6.5 for azimuthal and .42 for radial
# #plt.tight_layout(rect=(0., 0., 1, 1))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1., hspace=None)
# Out:
# mean: 0.1675708293914795, std: 0.3974066376686096
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
