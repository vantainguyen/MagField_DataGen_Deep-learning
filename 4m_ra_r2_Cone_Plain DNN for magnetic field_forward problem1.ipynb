# %% [markdown]
# # Plain-DNN for magnetic field

# %% [markdown]
# ## Navigating to the working directory containing the datasets and model

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
from platform import python_version
print(python_version())
# Out:
# 3.7.12

# %% [markdown]
# ## Checking the current working GPU

# %%
# !nvidia-smi
# Out:
# Sun Mar 13 12:16:38 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.51.05    Driver Version: 450.51.05    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:01:00.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |     29MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      2823      G   /usr/bin/X                         28MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Loading the datasets and doing feature engineering

# %%
# Loading data

import pickle
import os

# source_file_data_111 = '/content/drive/My Drive/part_C_all_1'
# os.chdir(source_file_data_111)

# with open('all_1_para', 'rb') as file_para:
#     para = pickle.load(file_para)
    
# with open('all_1_output_field', 'rb') as file_out:
#     output_field = pickle.load(file_out)
source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'
os.chdir(source_file)

with open('para_cone_4m', 'rb') as file_para:
    para = pickle.load(file_para)
    
with open('output_field_cone_4m', 'rb') as file_out:
    output_field = pickle.load(file_out)


# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
len(output_field)
# Out:
# 4000000

# %% [markdown]
# ## Cleaning data

# %%
# cleaning data
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle

random.seed(123)

para_np = np.array(para)
output_field_np = np.array(output_field)

index = 2

q1, q3 = np.percentile(output_field_np[:, index], [25, 75])

upper = q3 + 1.5*(q3-q1)
lower = q1 - 1.5*(q3-q1)

mask = (output_field_np[:, index] > lower)*(output_field_np[:, index] < upper)

mask_index = np.where(mask)[0]

clean_2 = output_field_np[:, index][mask]

para_2 = para_np[mask_index]

# %%
clean_2.shape
# Out:
# (2973750,)

# %%
import seaborn as sns
sns.distplot(clean_2, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.hist(clean_2)
# plt.hist(output_field_np[:, 0])
#sns.distplot(output_field_np[:, 0], kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
# Out:
# (array([  65956.,   91570.,  132138.,  208602.,  364356.,  814855.,
#         1104455.,   97908.,   54977.,   38933.]),
#  array([-1193.27656077, -1002.34087518,  -811.4051896 ,  -620.46950402,
#          -429.53381843,  -238.59813285,   -47.66244727,   143.27323831,
#           334.2089239 ,   525.14460948,   716.08029506]),
#  <BarContainer object of 10 artists>)

# %%
# mask = np.argwhere(output_field_np <= q3)
# mask.shape

from matplotlib import pyplot as plt

plt.hist(para_2[:,0])

#np.unique(output_field_np[:, 0], return_counts=True)
# Out:
# (array([375831., 358505., 339536., 321497., 302015., 285296., 269199.,
#         254531., 239709., 227631.]),
#  array([0.08726731, 0.21816684, 0.34906636, 0.47996589, 0.61086541,
#         0.74176494, 0.87266447, 1.00356399, 1.13446352, 1.26536305,
#         1.39626257]),
#  <BarContainer object of 10 artists>)

# %%
output_field_np.shape
# Out:
# (2000000, 3)

# %% [markdown]
# ## Feature engineering for clean data

# %%
# Feature engineering for clean datasets
# Feature engineering

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

import random
import numpy as np
import pickle

random.seed(123)

para_np = para_2 #np.array(para)
output_field_np = clean_2 #np.array(output_field)

#q1, q3 = np.percentile(output_field_np, [5, 95])

x_train, x_test, y_train, y_test = train_test_split(para_np, output_field_np, test_size=.10, shuffle=True)

x_sScaler = StandardScaler()
x_sScaler.fit(x_train)
s_x_train_scaled = x_sScaler.transform(x_train)
s_x_test_scaled = x_sScaler.transform(x_test)

y_sScaler = StandardScaler()
y_sScaler.fit(y_train.reshape(-1, 1))
s_y_train_scaled = y_sScaler.transform(y_train.reshape(-1, 1))
s_y_test_scaled = y_sScaler.transform(y_test.reshape(-1, 1))


# # Saving training, testing and scalers data


with open('re_s_x_train_scaled_az', 'wb') as filename:
  pickle.dump(s_x_train_scaled, filename)

with open('re_s_y_train_scaled_az', 'wb') as filename:
  pickle.dump(s_y_train_scaled, filename)

with open('re_s_x_test_scaled_az', 'wb') as filename:
  pickle.dump(s_x_test_scaled, filename)

with open('re_s_y_test_scaled_az', 'wb') as filename:
  pickle.dump(s_y_test_scaled, filename)

with open('re_x_sScaler_az', 'wb') as filename:
  pickle.dump(x_sScaler, filename)

with open('re_y_sScaler_az', 'wb') as filename:
  pickle.dump(y_sScaler, filename)

# %%
plt.hist(s_x_train_scaled)
# Out:
# (array([[     0.,  93443., 179395., 154704., 129095., 105286.,  85360.,
#           67187.,  50740.,  34790.],
#         [     0.,  88082., 191583., 154492., 122934.,  99835.,  82710.,
#           69851.,  60171.,  30342.],
#         [ 67959.,  76735.,  93243., 109897., 122767., 135234., 148256.,
#          145909.,      0.,      0.],
#         [ 32881., 103687., 130850., 118074., 111040., 115935., 133341.,
#          105383.,  48809.,      0.],
#         [     0., 129574., 151187., 129451., 109870., 105804., 102477.,
#          101927.,  69710.,      0.],
#         [     0.,      0., 433005.,      0.,      0.,      0., 466995.,
#               0.,      0.,      0.],
#         [     0.,      0., 466995.,      0.,      0.,      0., 433005.,
#               0.,      0.,      0.]]),
#  array([-2.08572623, -1.63026724, -1.17480824, -0.71934925, -0.26389025,
#          0.19156874,  0.64702774,  1.10248673,  1.55794573,  2.01340472,
#          2.46886372]),
#  <a list of 7 Lists of Patches objects>)

# %% [markdown]
# ## Loading ready processed datasets

# %%
import pickle
import os

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'

os.chdir(source_file)

with open('re_s_x_train_scaled_az', 'rb') as filename:
  s_x_train_scaled = pickle.load(filename)

with open('re_s_y_train_scaled_az', 'rb') as filename:
  s_y_train_scaled = pickle.load(filename)

with open('re_s_x_test_scaled_az', 'rb') as filename:
  s_x_test_scaled = pickle.load(filename)

with open('re_s_y_test_scaled_az', 'rb') as filename:
  s_y_test_scaled = pickle.load(filename)

with open('re_x_sScaler_az', 'rb') as filename:
  x_sScaler = pickle.load(filename)

with open('re_y_sScaler_az', 'rb') as filename:
  y_sScaler = pickle.load(filename)

# importing data for out of training intervals

# with open('out_s_x_test_scaled_200k', 'rb') as filename:
#   out_x_scaled = pickle.load(filename)

# with open('out_s_y_test_scaled_200k', 'rb') as filename:
#   out_y_scaled = pickle.load(filename)

# %%
import numpy as np
min_ = np.min(s_y_train_scaled)
max_ = np.max(s_y_train_scaled)

out_min_ = np.min(out_y_scaled)
out_max_ = np.max(out_y_scaled)
print(f'Field interval for the training data is: [{min_}, {max_}]')
print(f'Field interval for the out of training intervals is: [{out_min_}, {out_max_}]')
# Out:
# Field interval for the training data is: [-23.610358434445427, 23.999540757658966]
# Field interval for the out of training intervals is: [-2.3426246433144176, 2.2994854937939446]

# %%
with open('out_para_200k', 'rb') as filename:
  out_para_scaled = pickle.load(filename)

# %%
x_train.shape
# Out:
# (1372003, 9)

# %% [markdown]
# ## PlainDNN model development

# %%
# Plain DNN model


import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation


# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

class PlainDNNModel(tf.keras.Model):
    def __init__(self):
        
        super(PlainDNNModel, self).__init__()
        
        self.dense1_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense1_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense2_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense2_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)


        self.dense3_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_2 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_3 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_4 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
        self.dense3_o = tf.keras.layers.Dense(1)

        
    def call(self, inputs):
        
        x_1 = self.dense1_1(inputs)
        x_1 = self.dense1_2(x_1)
        x_1 = self.dense1_3(x_1)

        
        x_2 = self.dense2_1(x_1)
        x_2 = self.dense2_2(x_2)
        x_2 = self.dense2_3(x_2)

        x_3 = self.dense3_1(x_2)
        x_3 = self.dense3_2(x_3)
        x_3 = self.dense3_3(x_3)
        x_3 = self.dense3_4(x_3)
        x_3 = self.dense3_o(x_3)
        
        
        return x_3
    


PlainModel = PlainDNNModel()  


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999)

PlainModel.compile(optimizer=opt, loss='mse')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-6-b396cdf49daa> in <module>
#      76
#      77
# ---> 78 PlainModel = PlainDNNModel()
#      79
#      80
#
# <ipython-input-6-b396cdf49daa> in __init__(self)
#      35     def __init__(self):
#      36
# ---> 37         super(PlainDNNModel, self).__init__()
#      38
#      39         self.dense1_1 = tf.keras.layers.Dense(796, activation=tf.nn.relu)
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in __init__(self, *args, **kwargs)
#     291     self._steps_per_execution = None
#     292
# --> 293     self._init_batch_counters()
#     294     self._base_model_initialized = True
#     295
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     515     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     516     try:
# --> 517       result = method(self, *args, **kwargs)
#     518     finally:
#     519       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/keras/engine/training.py in _init_batch_counters(self)
#     299     # `evaluate`, and `predict`.
#     300     agg = variables.VariableAggregationV2.ONLY_FIRST_REPLICA
# --> 301     self._train_counter = variables.Variable(0, dtype='int64', aggregation=agg)
#     302     self._test_counter = variables.Variable(0, dtype='int64', aggregation=agg)
#     303     self._predict_counter = variables.Variable(
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     260       return cls._variable_v1_call(*args, **kwargs)
#     261     elif cls is Variable:
# --> 262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
#     264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     242     if aggregation is None:
#     243       aggregation = VariableAggregation.NONE
# --> 244     return previous_getter(
#     245         initial_value=initial_value,
#     246         trainable=trainable,
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in <lambda>(**kws)
#     235                         shape=None):
#     236     """Call on Variable class. Useful to force the signature."""
# --> 237     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     238     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     239       previous_getter = _make_getter(getter, previous_getter)
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/variable_scope.py in default_variable_creator_v2(next_creator, **kwargs)
#    2652   shape = kwargs.get("shape", None)
#    2653
# -> 2654   return resource_variable_ops.ResourceVariable(
#    2655       initial_value=initial_value,
#    2656       trainable=trainable,
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     262       return cls._variable_v2_call(*args, **kwargs)
#     263     else:
# --> 264       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     265
#     266
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1572       self._init_from_proto(variable_def, import_scope=import_scope)
#    1573     else:
# -> 1574       self._init_from_args(
#    1575           initial_value=initial_value,
#    1576           trainable=trainable,
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1715               self._update_uid = initial_value.checkpoint_position.restore_uid
#    1716               initial_value = initial_value.wrapped_value
# -> 1717             initial_value = ops.convert_to_tensor(initial_value,
#    1718                                                   name="initial_value",
#    1719                                                   dtype=dtype)
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1538
#    1539     if ret is None:
# -> 1540       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1541
#    1542     if ret is NotImplemented:
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     262     ValueError: if called on a symbolic tensor.
#     263   """
# --> 264   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     265                         allow_broadcast=True)
#     266
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     274       with trace.Trace("tf.constant"):
#     275         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 276     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277
#     278   g = ops.get_default_graph()
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     299 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     300   """Implementation of eager constant."""
# --> 301   t = convert_to_eager_tensor(value, ctx, dtype)
#     302   if shape is None:
#     303     return t
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      95     except AttributeError:
#      96       dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97   ctx.ensure_initialized()
#      98   return ops.EagerTensor(value, ctx.device_name, dtype)
#      99
#
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/tensorflow/python/eager/context.py in ensure_initialized(self)
#     524         if self._use_tfrt is not None:
#     525           pywrap_tfe.TFE_ContextOptionsSetTfrt(opts, self._use_tfrt)
# --> 526         context_handle = pywrap_tfe.TFE_NewContext(opts)
#     527       finally:
#     528         pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: CUDA runtime implicit initialization on GPU:0 failed. Status: out of memory

# %% [markdown]
# ## Loading pre-trained model

# %%
import tensorflow as tf
import os
import numpy as np
from tensorflow.keras.layers import Add, Concatenate, Activation

#source_file = '/content/drive/My Drive/Data_and_model/Datasets_for_magfield'
# Define a customised loss function

def loss_func(y_true, y_pred): 
    
    # Root mean square loss
    squared_difference = tf.square(y_true - y_pred)
    mean_square_loss = tf.reduce_mean(squared_difference, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss + 1e-20)
    
    return root_mean_square_loss 
 
def loss_func_with_weights(y_true, y_pred): 

    alpha = 3.0
    beta = 5.0
    sq = tf.square(y_true - y_pred)
    sq1 = tf.reshape(sq[:, 0], shape=(-1, 1)) 
    sq2 = tf.reshape(alpha*sq[:, 1], shape=(-1, 1))
    sq3 = tf.reshape(beta*sq[:, 2], shape=(-1, 1))
    sq4 = Concatenate(axis=-1)([sq1, sq2, sq3])
    mean_square_loss = tf.reduce_mean(sq4, axis=-1)
    root_mean_square_loss = tf.sqrt(mean_square_loss+1e-20)
    
    return root_mean_square_loss 

source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az') # ----> this filder is for the radial component
if os.getcwd != source_file_model:
  os.chdir(source_file_model)

PlainModel = PlainDNNModel()  
PlainModel.load_weights('PlainDNN_400_796_clean') #PlainDNN_3001_noco


opt = tf.keras.optimizers.Adam(learning_rate=0.001, amsgrad=True, beta_1=.9, beta_2=.9999 )
#Hmodel = tf.keras.models.load_model('HDNN_300', compile=False)

PlainModel.compile(optimizer=opt, loss=loss_func) # the loss_func is good enough we don't need the loss_func_with_weights

# %%
os.getcwd()
# Out:
# '/home/opc/vantai/Datasets_for_magfield/re_HDNNmodel'

# %%
decay_steps = 40
step = [10, 100, 200, 300]
decay_rate = 0.5

for step in step:
  print(decay_rate**(step/decay_steps))
# Out:
# 0.8408964152537145
# 0.1767766952966369
# 0.03125
# 0.005524271728019903

# %%
y_train.shape
# Out:
# (900000,)

# %% [markdown]
# ## Model training

# %%
import pickle
import time
import os
from datetime import datetime
# %load_ext tensorboard

now = datetime.now()
#os.mkdir('re_HDNNmodel_IQR_az')

source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az')
if os.getcwd != source_file_model:
  os.chdir(source_file_model)



filepath = os.path.join(os.getcwd(), 'PlainDNN_400_796_clean')

modelcheckpoint = tf.keras.callbacks.ModelCheckpoint(filepath=filepath, monitor='val_loss', 
                                                     mode='min', verbose=1, save_best_only=True, save_weights_only=True)

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', verbose=1, mode='min', patience=20, min_delta=0.00005)

new_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', mode='min', verbose=1, patience=10, 
                                              factor=1/10, min_lr=1e-5)

path = "logs/fit/" + now.strftime("%Y/%m/%/d, %H/%M")

#tensorboard = tf.keras.callbacks.TensorBoard(log_dir=path, histogram_freq=1)

st = time.time()

history = PlainModel.fit(s_x_train_scaled, s_y_train_scaled, validation_split=.10, 
                     batch_size=512, epochs=400, callbacks=[earlystopping, modelcheckpoint, new_lr]) #[earlystopping, modelcheckpoint, new_lr]

used_time = time.time() - st

with open('p796_history_400_clean', 'wb') as filename:
  pickle.dump(history.history, filename)

with open('p796_used_time_400_clean', 'wb') as filename:
  pickle.dump(used_time, filename)

#oss: 0.1562 - val_loss: 0.1343
# Out:
# Epoch 1/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.1318 - val_loss: 0.0791
#
# Epoch 00001: val_loss improved from inf to 0.07906, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 2/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0412 - val_loss: 0.0321
#
# Epoch 00002: val_loss improved from 0.07906 to 0.03212, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 3/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0313 - val_loss: 0.0210
#
# Epoch 00003: val_loss improved from 0.03212 to 0.02098, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 4/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0285 - val_loss: 0.0248
#
# Epoch 00004: val_loss did not improve from 0.02098
# Epoch 5/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0260 - val_loss: 0.0210
#
# Epoch 00005: val_loss did not improve from 0.02098
# Epoch 6/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0221 - val_loss: 0.0180
#
# Epoch 00006: val_loss improved from 0.02098 to 0.01798, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 7/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0212 - val_loss: 0.0206
#
# Epoch 00007: val_loss did not improve from 0.01798
# Epoch 8/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0200 - val_loss: 0.0144
#
# Epoch 00008: val_loss improved from 0.01798 to 0.01440, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 9/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0204 - val_loss: 0.0203
#
# Epoch 00009: val_loss did not improve from 0.01440
# Epoch 10/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0200 - val_loss: 0.0168
#
# Epoch 00010: val_loss did not improve from 0.01440
# Epoch 11/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0168 - val_loss: 0.0147
#
# Epoch 00011: val_loss did not improve from 0.01440
# Epoch 12/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0155 - val_loss: 0.0133
#
# Epoch 00012: val_loss improved from 0.01440 to 0.01335, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 13/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0151 - val_loss: 0.0126
#
# Epoch 00013: val_loss improved from 0.01335 to 0.01265, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 14/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0145 - val_loss: 0.0113
#
# Epoch 00014: val_loss improved from 0.01265 to 0.01132, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 15/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0143 - val_loss: 0.0157
#
# Epoch 00015: val_loss did not improve from 0.01132
# Epoch 16/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0138 - val_loss: 0.0132
#
# Epoch 00016: val_loss did not improve from 0.01132
# Epoch 17/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0132 - val_loss: 0.0126
#
# Epoch 00017: val_loss did not improve from 0.01132
# Epoch 18/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0130 - val_loss: 0.0128
#
# Epoch 00018: val_loss did not improve from 0.01132
# Epoch 19/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0125 - val_loss: 0.0105
#
# Epoch 00019: val_loss improved from 0.01132 to 0.01055, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 20/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0116 - val_loss: 0.0093
#
# Epoch 00020: val_loss improved from 0.01055 to 0.00934, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 21/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0120 - val_loss: 0.0101
#
# Epoch 00021: val_loss did not improve from 0.00934
# Epoch 22/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0119 - val_loss: 0.0101
#
# Epoch 00022: val_loss did not improve from 0.00934
# Epoch 23/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0109 - val_loss: 0.0136
#
# Epoch 00023: val_loss did not improve from 0.00934
# Epoch 24/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0112 - val_loss: 0.0129
#
# Epoch 00024: val_loss did not improve from 0.00934
# Epoch 25/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0111 - val_loss: 0.0115
#
# Epoch 00025: val_loss did not improve from 0.00934
# Epoch 26/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0108 - val_loss: 0.0128
#
# Epoch 00026: val_loss did not improve from 0.00934
# Epoch 27/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0108 - val_loss: 0.0110
#
# Epoch 00027: val_loss did not improve from 0.00934
# Epoch 28/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0098 - val_loss: 0.0101
#
# Epoch 00028: val_loss did not improve from 0.00934
# Epoch 29/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0114 - val_loss: 0.0087
#
# Epoch 00029: val_loss improved from 0.00934 to 0.00871, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 30/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0098 - val_loss: 0.0134
#
# Epoch 00030: val_loss did not improve from 0.00871
# Epoch 31/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0101 - val_loss: 0.0103
#
# Epoch 00031: val_loss did not improve from 0.00871
# Epoch 32/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0099 - val_loss: 0.0121
#
# Epoch 00032: val_loss did not improve from 0.00871
# Epoch 33/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0097 - val_loss: 0.0112
#
# Epoch 00033: val_loss did not improve from 0.00871
# Epoch 34/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0098 - val_loss: 0.0082
#
# Epoch 00034: val_loss improved from 0.00871 to 0.00817, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 35/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0098 - val_loss: 0.0071
#
# Epoch 00035: val_loss improved from 0.00817 to 0.00710, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 36/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0092 - val_loss: 0.0107
#
# Epoch 00036: val_loss did not improve from 0.00710
# Epoch 37/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0091 - val_loss: 0.0065
#
# Epoch 00037: val_loss improved from 0.00710 to 0.00651, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 38/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0129 - val_loss: 0.0131
#
# Epoch 00038: val_loss did not improve from 0.00651
# Epoch 39/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0134 - val_loss: 0.0085
#
# Epoch 00039: val_loss did not improve from 0.00651
# Epoch 40/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0111 - val_loss: 0.0106
#
# Epoch 00040: val_loss did not improve from 0.00651
# Epoch 41/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0099 - val_loss: 0.0104
#
# Epoch 00041: val_loss did not improve from 0.00651
# Epoch 42/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0091 - val_loss: 0.0085
#
# Epoch 00042: val_loss did not improve from 0.00651
# Epoch 43/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0095 - val_loss: 0.0068
#
# Epoch 00043: val_loss did not improve from 0.00651
# Epoch 44/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0088 - val_loss: 0.0093
#
# Epoch 00044: val_loss did not improve from 0.00651
# Epoch 45/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0093 - val_loss: 0.0099
#
# Epoch 00045: val_loss did not improve from 0.00651
# Epoch 46/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0079 - val_loss: 0.0112
#
# Epoch 00046: val_loss did not improve from 0.00651
# Epoch 47/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0081 - val_loss: 0.0086
#
# Epoch 00047: val_loss did not improve from 0.00651
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 48/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0033 - val_loss: 0.0031
#
# Epoch 00048: val_loss improved from 0.00651 to 0.00310, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 49/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0023 - val_loss: 0.0033
#
# Epoch 00049: val_loss did not improve from 0.00310
# Epoch 50/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0021 - val_loss: 0.0030
#
# Epoch 00050: val_loss improved from 0.00310 to 0.00299, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 51/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0021 - val_loss: 0.0028
#
# Epoch 00051: val_loss improved from 0.00299 to 0.00278, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 52/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0019 - val_loss: 0.0026
#
# Epoch 00052: val_loss improved from 0.00278 to 0.00261, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 53/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0017 - val_loss: 0.0029
#
# Epoch 00053: val_loss did not improve from 0.00261
# Epoch 54/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0017 - val_loss: 0.0025
#
# Epoch 00054: val_loss improved from 0.00261 to 0.00253, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 55/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0016 - val_loss: 0.0028
#
# Epoch 00055: val_loss did not improve from 0.00253
# Epoch 56/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0015 - val_loss: 0.0024
#
# Epoch 00056: val_loss improved from 0.00253 to 0.00244, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 57/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0016 - val_loss: 0.0028
#
# Epoch 00057: val_loss did not improve from 0.00244
# Epoch 58/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 0.0014 - val_loss: 0.0025
#
# Epoch 00058: val_loss did not improve from 0.00244
# Epoch 59/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0014 - val_loss: 0.0022
#
# Epoch 00059: val_loss improved from 0.00244 to 0.00225, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 60/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0014 - val_loss: 0.0026
#
# Epoch 00060: val_loss did not improve from 0.00225
# Epoch 61/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0013 - val_loss: 0.0022
#
# Epoch 00061: val_loss improved from 0.00225 to 0.00215, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 62/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0013 - val_loss: 0.0025
#
# Epoch 00062: val_loss did not improve from 0.00215
# Epoch 63/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0014 - val_loss: 0.0031
#
# Epoch 00063: val_loss did not improve from 0.00215
# Epoch 64/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0014 - val_loss: 0.0026
#
# Epoch 00064: val_loss did not improve from 0.00215
# Epoch 65/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0013 - val_loss: 0.0023
#
# Epoch 00065: val_loss did not improve from 0.00215
# Epoch 66/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0013 - val_loss: 0.0025
#
# Epoch 00066: val_loss did not improve from 0.00215
# Epoch 67/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0012 - val_loss: 0.0024
#
# Epoch 00067: val_loss did not improve from 0.00215
# Epoch 68/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0012 - val_loss: 0.0021
#
# Epoch 00068: val_loss improved from 0.00215 to 0.00212, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 69/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0012 - val_loss: 0.0022
#
# Epoch 00069: val_loss did not improve from 0.00212
# Epoch 70/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0022
#
# Epoch 00070: val_loss did not improve from 0.00212
# Epoch 71/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0021
#
# Epoch 00071: val_loss improved from 0.00212 to 0.00208, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 72/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0012 - val_loss: 0.0020
#
# Epoch 00072: val_loss improved from 0.00208 to 0.00204, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 73/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0021
#
# Epoch 00073: val_loss did not improve from 0.00204
# Epoch 74/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0025
#
# Epoch 00074: val_loss did not improve from 0.00204
# Epoch 75/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0022
#
# Epoch 00075: val_loss did not improve from 0.00204
# Epoch 76/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0012 - val_loss: 0.0023
#
# Epoch 00076: val_loss did not improve from 0.00204
# Epoch 77/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0011 - val_loss: 0.0033
#
# Epoch 00077: val_loss did not improve from 0.00204
# Epoch 78/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0010 - val_loss: 0.0020
#
# Epoch 00078: val_loss improved from 0.00204 to 0.00197, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 79/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.9791e-04 - val_loss: 0.0019
#
# Epoch 00079: val_loss improved from 0.00197 to 0.00194, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 80/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.6946e-04 - val_loss: 0.0024
#
# Epoch 00080: val_loss did not improve from 0.00194
# Epoch 81/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.9512e-04 - val_loss: 0.0019
#
# Epoch 00081: val_loss improved from 0.00194 to 0.00186, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 82/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.9304e-04 - val_loss: 0.0021
#
# Epoch 00082: val_loss did not improve from 0.00186
# Epoch 83/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.4531e-04 - val_loss: 0.0017
#
# Epoch 00083: val_loss improved from 0.00186 to 0.00174, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 84/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.9098e-04 - val_loss: 0.0018
#
# Epoch 00084: val_loss did not improve from 0.00174
# Epoch 85/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 9.0273e-04 - val_loss: 0.0018
#
# Epoch 00085: val_loss did not improve from 0.00174
# Epoch 86/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 8.3528e-04 - val_loss: 0.0021
#
# Epoch 00086: val_loss did not improve from 0.00174
# Epoch 87/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 8.2681e-04 - val_loss: 0.0018
#
# Epoch 00087: val_loss did not improve from 0.00174
# Epoch 88/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 9.0096e-04 - val_loss: 0.0024
#
# Epoch 00088: val_loss did not improve from 0.00174
# Epoch 89/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 9.6638e-04 - val_loss: 0.0018
#
# Epoch 00089: val_loss did not improve from 0.00174
# Epoch 90/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 8.2961e-04 - val_loss: 0.0019
#
# Epoch 00090: val_loss did not improve from 0.00174
# Epoch 91/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 9.2298e-04 - val_loss: 0.0022
#
# Epoch 00091: val_loss did not improve from 0.00174
# Epoch 92/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 8.0382e-04 - val_loss: 0.0020
#
# Epoch 00092: val_loss did not improve from 0.00174
# Epoch 93/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 0.0013 - val_loss: 0.0018
#
# Epoch 00093: val_loss did not improve from 0.00174
#
# Epoch 00093: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 94/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 6.1879e-04 - val_loss: 0.0016
#
# Epoch 00094: val_loss improved from 0.00174 to 0.00162, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 95/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.6853e-04 - val_loss: 0.0016
#
# Epoch 00095: val_loss improved from 0.00162 to 0.00161, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 96/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.6224e-04 - val_loss: 0.0016
#
# Epoch 00096: val_loss did not improve from 0.00161
# Epoch 97/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.6707e-04 - val_loss: 0.0016
#
# Epoch 00097: val_loss improved from 0.00161 to 0.00160, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 98/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.7051e-04 - val_loss: 0.0016
#
# Epoch 00098: val_loss improved from 0.00160 to 0.00160, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 99/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.6087e-04 - val_loss: 0.0016
#
# Epoch 00099: val_loss did not improve from 0.00160
# Epoch 100/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.2932e-04 - val_loss: 0.0016
#
# Epoch 00100: val_loss improved from 0.00160 to 0.00159, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 101/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.4643e-04 - val_loss: 0.0016
#
# Epoch 00101: val_loss did not improve from 0.00159
# Epoch 102/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.4707e-04 - val_loss: 0.0016
#
# Epoch 00102: val_loss improved from 0.00159 to 0.00159, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 103/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.3632e-04 - val_loss: 0.0016
#
# Epoch 00103: val_loss did not improve from 0.00159
# Epoch 104/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.1709e-04 - val_loss: 0.0016
#
# Epoch 00104: val_loss improved from 0.00159 to 0.00159, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
#
# Epoch 00104: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 105/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.2520e-04 - val_loss: 0.0016
#
# Epoch 00105: val_loss did not improve from 0.00159
# Epoch 106/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.3152e-04 - val_loss: 0.0016
#
# Epoch 00106: val_loss did not improve from 0.00159
# Epoch 107/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.2257e-04 - val_loss: 0.0016
#
# Epoch 00107: val_loss improved from 0.00159 to 0.00159, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 108/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.3061e-04 - val_loss: 0.0016
#
# Epoch 00108: val_loss improved from 0.00159 to 0.00158, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 109/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.4110e-04 - val_loss: 0.0016
#
# Epoch 00109: val_loss did not improve from 0.00158
# Epoch 110/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.4023e-04 - val_loss: 0.0016
#
# Epoch 00110: val_loss improved from 0.00158 to 0.00158, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 111/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.4289e-04 - val_loss: 0.0016
#
# Epoch 00111: val_loss did not improve from 0.00158
# Epoch 112/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.2702e-04 - val_loss: 0.0016
#
# Epoch 00112: val_loss improved from 0.00158 to 0.00158, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 113/400
# 4705/4705 [==============================] - 37s 8ms/step - loss: 5.0548e-04 - val_loss: 0.0016
#
# Epoch 00113: val_loss did not improve from 0.00158
# Epoch 114/400
# 4705/4705 [==============================] - 36s 8ms/step - loss: 5.2147e-04 - val_loss: 0.0016
#
# Epoch 00114: val_loss improved from 0.00158 to 0.00158, saving model to /scratch/cvl/uqvngu19/Data_and_model/Cone_data_4m/re_HDNNmodel_IQR_az/PlainDNN_400_796_clean
# Epoch 00114: early stopping

# %% [markdown]
# ## History plotting

# %%
import pickle
import os
import pandas as pd
import matplotlib.pyplot as plt

source_file = '/clusterdata/uqvngu19/scratch/Data_and_model/Cone_data_4m'
source_file_model = os.path.join(source_file, 're_HDNNmodel_IQR_az')

if os.getcwd() != source_file_model:
  os.chdir(source_file_model)


with open('p796_history_400_clean', 'rb') as filename:
  hist1 = pickle.load(filename)

pdhist1 = pd.DataFrame(hist1)
#pdhist2 = pd.DataFrame(hist2)


#pdhist = pd.concat([pdhist1, pdhist2], axis=0, ignore_index_=True)


pdhist1['loss'].plot(linestyle='--', c='b')
pdhist1['val_loss'].plot(c='r')

plt.legend(loc='upper right', fontsize=16)
plt.grid()
plt.xlim(0, 116)
plt.ylim(0, 0.12)

plt.xlabel('Epochs (CRa)', fontsize=16)
plt.ylabel('Errors', fontsize=16)

#plt.text(170, .05, r"$\hat\alpha = 1.0,$",fontsize=12)
#plt.text(170, .04, r"$\hat\beta = 1.0$",fontsize=12)

#plt.text(310, .05, r"$\hat\alpha = 1.8,$",fontsize=12)
#plt.text(310, .04, r"$\hat\beta = 2.5$",fontsize=12)

#plt.text(410, .05, r"$\hat\alpha = 3.0,$",fontsize=12)
#plt.text(410, .04, r"$\hat\beta = 5.0$",fontsize=12)

#plt.vlines(300, ymin=0, ymax=.12, linestyles='dotted')
#plt.vlines(400, ymin=0, ymax=.12, linestyles='dotted')
# Out:
# Text(0, 0.5, 'Errors')

# %%
PlainModel.summary()
# Out:
# Model: "plain_dnn_model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_110 (Dense)            multiple                  7960
# _________________________________________________________________
# dense_111 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_112 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_113 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_114 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_115 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_116 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_117 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_118 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_119 (Dense)            multiple                  634412
# _________________________________________________________________
# dense_120 (Dense)            multiple                  2391
# =================================================================
# Total params: 5,720,059
# Trainable params: 5,720,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model testing

# %%
# Predicting the results
s_y_predicted_scaled = PlainModel.predict(s_x_test_scaled)

# Predicting the results
#y_predicted = PlainModel.predict(x_test)

# %%
out_y_predicted_scaled = PlainModel.predict(out_x_scaled)

# %%
# Testing the model
from sklearn.metrics import r2_score, mean_squared_error
r2_score(s_y_test_scaled, s_y_predicted_scaled)

#r2_score(s_y_test_scaled[:, 0], s_y_predicted_scaled[:, 0])
# Out:
# 0.9982394797901879

# %%
import scipy.stats as ss


ss.pearsonr(np.squeeze(s_y_test_scaled), np.squeeze(s_y_predicted_scaled))
# Out:
# (0.9991193747052807, 0.0)

# %%
y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled).astype(np.float32)
y_test = y_sScaler.inverse_transform(s_y_test_scaled).astype(np.float32)

# %%
print(y_pred[10:20])
print(y_test[10:20])
# Out:
# [[   5.0240006]
#  [ -14.875413 ]
#  [-183.41264  ]
#  [-268.5411   ]
#  [-207.75182  ]
#  [ 185.64262  ]
#  [ -72.76418  ]
#  [  -2.4926312]
#  [-840.30786  ]
#  [  89.25334  ]]
# [[   4.5401917]
#  [ -15.17775  ]
#  [-182.62498  ]
#  [-269.20496  ]
#  [-209.28828  ]
#  [ 187.41087  ]
#  [ -71.917725 ]
#  [  -2.221205 ]
#  [-840.38806  ]
#  [  91.13531  ]]

# %%
from sklearn.metrics import r2_score, mean_squared_error

np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 12.795989

# %%
12.795/np.subtract(*np.percentile(y_test, [5, 95]))
# Out:
# -0.012346980898097621

# %%
np.subtract(*np.percentile(y_test, [5, 95]))
# Out:
# -1036.2857208251944

# %%
import matplotlib.pyplot as plt 

y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled)
a, b = np.polyfit(np.squeeze(y_test), np.squeeze(y_pred), 1)
plt.scatter(y_test, y_pred)
plt.plot(y_test, a*y_test+b, color='r')
plt.xlabel('Ground truth field (A/m) (CRa)', fontsize=16)
plt.ylabel('Predicted field (A/m)', fontsize=16)
plt.grid('on')

# %%
with open('out_para_cone_dataset', 'rb') as filename:
  out_x_scaled = pickle.load(filename)

with open('out_H_cone_dataset', 'rb') as filename:
  out_y_scaled = pickle.load(filename)

# %%
x = x_sScaler.transform(out_x_scaled)
y = y_sScaler.transform(np.array(out_y_scaled)[:, 2].reshape(-1, 1))

# %%
np.array(out_x_scaled).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65036579a405> in <module>
# ----> 1 np.array(out_x_scaled).shape
#
# NameError: name 'np' is not defined

# %%
y_pred = y_sScaler.inverse_transform(s_y_predicted_scaled).astype(np.float32)
y_test = y_sScaler.inverse_transform(s_y_test_scaled).astype(np.float32)

# %%
# Plotting pairs
# Not normalized
import seaborn as sns
index_ = 0

#vmin = np.min(s_y_test_scaled[:, index_])
#vmax = np.max(s_y_test_scaled[:, index_])
cmap = 'YlGnBu'
 # 0 for axial, 1 for azimuthal and 2 for radial components

height = [0.00148, 0.788, 0.00395]
low = [-0.000227, -0.12, -0.000588]
plt.figure(figsize=(10, 14))

interq_955 = np.subtract(*np.percentile(y_test, [95, 5]))
errors = abs(y_pred - y_test)*100/interq_955


# errors = (s_y_predicted_scaled[:, index_+1].reshape(400000,-1)-s_y_test_scaled[:, index_+1].reshape(400000,-1))*100/(
#     np.max(s_y_test_scaled[:, index_+1]) - np.min(s_y_test_scaled[:, index_+1]))



plt.subplot(342)
mean = np.mean(errors)
std = np.std(errors)

print('mean: {}, std: {}'.format(mean, std))

sns.distplot(errors, kde=True, hist=False, rug=False, kde_kws={"shade": True, "bw_adjust": 1, "cut":0, "bw_method": 'silverman'}, color='b')
#sns.kdeplot(data=errors, fill=True)
plt.xlim(-5, 5)
plt.text(-7, -0.3, 'ND (%) (CRa)', fontsize=16)
#plt.text(-20, 1.6*low[index_+1], 'j) Azimuthal component', fontsize=12)
# #plt.xlabel('b) Azimuthal component', fontsize=12)
plt.ylabel('Kernel density estimation', fontsize=16)
plt.text(-9, 2.1, '\u03BC = {:2.2}, \u03C3 = {:0.3}'.format(mean, std), fontsize=16) # height index_ .2 for axial; = 6.5 for azimuthal and .42 for radial
# #plt.tight_layout(rect=(0., 0., 1, 1))
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=1., hspace=None)
# Out:
# mean: 0.2719004154205322, std: 1.2044854164123535
# /scratch/cvl/uqvngu19/miniconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
